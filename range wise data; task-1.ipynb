# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import sys

# %%
df2 = pd.read_csv("WorldPopulationByAge2020.csv")
df2.head()
# Out:
#   0 - Custom (for age range) Population Categories  \
# 0                                             Male
# 1                                           Female
# 2                                            Total
#
#    1 - Afghanistan (for age range) 0-19  \
# 0                                 10709
# 1                                 10197
# 2                                 20906
#
#    2 - Afghanistan_1 (for age range) 20-39  \
# 0                                     5994
# 1                                     5574
# 2                                    11568
#
#    3 - Afghanistan_2 (for age range) 40-59  \
# 0                                     2485
# 1                                     2316
# 2                                     4801
#
#    4 - Afghanistan_3 (for age range) 60  5 - Africa (for age range) 0-19  \
# 0                                   781                           344109
# 1                                   858                           334982
# ...

# %%
df2.iloc[[0, 1]] = df2.iloc[[1, 0]].values

# %%
df2.head()
# Out:
#   0 - Custom (for age range) Population Categories  \
# 0                                           Female
# 1                                             Male
# 2                                            Total
#
#    1 - Afghanistan (for age range) 0-19  \
# 0                                 10197
# 1                                 10709
# 2                                 20906
#
#    2 - Afghanistan_1 (for age range) 20-39  \
# 0                                     5574
# 1                                     5994
# 2                                    11568
#
#    3 - Afghanistan_2 (for age range) 40-59  \
# 0                                     2316
# 1                                     2485
# 2                                     4801
#
#    4 - Afghanistan_3 (for age range) 60  5 - Africa (for age range) 0-19  \
# 0                                   858                           334982
# 1                                   781                           344109
# ...

# %%
headers = df2.columns.tolist()
headers
# Out:
# ['0 - Custom (for age range) Population Categories',
#  '1 - Afghanistan (for age range) 0-19',
#  '2 - Afghanistan_1 (for age range) 20-39',
#  '3 - Afghanistan_2 (for age range) 40-59',
#  '4 - Afghanistan_3 (for age range) 60',
#  '5 - Africa (for age range) 0-19',
#  '6 - Africa_4 (for age range) 20-39',
#  '7 - Africa_5 (for age range) 40-59',
#  '8 - Africa_6 (for age range) 60',
#  '9 - African Group (for age range) 0-19',
#  '10 - African Group_7 (for age range) 20-39',
#  '11 - African Group_8 (for age range) 40-59',
#  '12 - African Group_9 (for age range) 60',
#  '13 - African Union (for age range) 0-19',
#  '14 - African Union_10 (for age range) 20-39',
#  '15 - African Union_11 (for age range) 40-59',
#  '16 - African Union_12 (for age range) 60',
#  '17 - African Union: Central Africa (for age range) 0-19',
#  '18 - African Union: Central Africa_13 (for age range) 20-39',
#  '19 - African Union: Central Africa_14 (for age range) 40-59',
# ...

# %%
a = input("select any one country from the above list: ")
b = input("please write what range did you select for the country: ")
c = input("write the serial number of the country: ")
d = int(c)
# Out:
# select any one country from the above list: Afghanistan
# please write what range did you select for the country: 60+
# write the serial number of the country: 4

# %%
d
# Out:
# 4

# %%
b
# Out:
# '60+'

# %%
x = df2.iloc[0:, 0]
y = df2.iloc[0:, d]

# %%
plt.plot(x, y)
plt.xlabel("population categories")
plt.ylabel(f"range of age is: {b}")
plt.title(a)
plt.show()

# %%
plt.bar(x, y)
plt.xlabel("population categories")
plt.ylabel(f"range of age is: {b}")
plt.title(a)
plt.show()
